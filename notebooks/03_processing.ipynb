# %%
import pandas as pd

# %%
df = pd.read_csv(os.path.join(INTERIM_DATA_DIR, 'interim\precos_comb_normalized.csv' ))

# %%
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# np.float64(2424.666248321533)

# %%
df.columns
# Out:
# Index(['regiao', 'estado', 'municipio', 'posto', 'bairro', 'produto',
#        'data_da_coleta', 'valor_de_venda', 'unidade_de_medida', 'bandeira'],
#       dtype='object')

# %% [markdown]
# Aqui, podemos perceber que todas as colunas são do mesmo objeto, até as numéricas, a proxima tarefa, será alterar o tipo de dados

# %%
from os import replace
df[['regiao', 'estado', 'produto','unidade_de_medida', 'bandeira']] = df[['regiao', 'estado', 'produto','unidade_de_medida', 'bandeira']].astype('category')
df[['municipio', 'posto', 'bairro']] = df[['municipio', 'posto', 'bairro']].astype('string')

df['data_da_coleta'] = pd.to_datetime(df['data_da_coleta'], dayfirst=True)

df['valor_de_venda'] = (df['valor_de_venda']
                        .str.replace(',','.')
                        .astype('float32'))

# %%
df.dtypes
# Out:
# regiao                     category
# estado                     category
# municipio            string[python]
# posto                string[python]
# bairro               string[python]
# produto                    category
# data_da_coleta       datetime64[ns]
# valor_de_venda              float32
# unidade_de_medida          category
# bandeira                   category
# dtype: object
